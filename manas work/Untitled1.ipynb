# %%
import pandas as pd

# %%
data=pd.read_csv("./data/data4.csv",delimiter=",")

# %%
data.head(n=50)
# Out:
#      sno                  name  sex   age  cat    party        symb    genral  \
# 0    1.0          SHARAD KUMAR    M  40.0  GEN     AAAP       Broom   95887.0
# 1    2.0     NEEL DAMAN KHATRI    M  44.0  GEN      BJP       Lotus   54610.0
# 2    3.0  PRAVEEN KUMAR BHUGRA    M  46.0  GEN      INC        Hand    4619.0
# 3    4.0      ROOPESH BHARDWAJ    M  40.0  GEN      BSP    Elephant    1648.0
# 4    5.0     None of the Above  NaN   NaN  NaN     NOTA        NOTA     764.0
# 5    6.0            BRIJ MOHAN    M  37.0  GEN      SHS       Bow &     477.0
# 6    NaN                   NaN  NaN   NaN  NaN      NaN       Arrow       NaN
# 7    7.0              SURENDER    M  48.0  GEN  CPI(ML)       Cup &     362.0
# 8    NaN                   NaN  NaN   NaN  NaN      (L)      Saucer       NaN
# 9    8.0           MANOJ KUMAR    M  42.0  GEN      IND         Hat     218.0
# 10   9.0           AJAY MUDGIL    M  30.0  GEN      IND     Coconut     191.0
# ...

# %%
data=data[pd.notnull(data["sno"])]

# %%
data.head(n=10)
# Out:
#     sno                  name  sex   age  cat    party      symb    genral  \
# 0   1.0          SHARAD KUMAR    M  40.0  GEN     AAAP     Broom   95887.0
# 1   2.0     NEEL DAMAN KHATRI    M  44.0  GEN      BJP     Lotus   54610.0
# 2   3.0  PRAVEEN KUMAR BHUGRA    M  46.0  GEN      INC      Hand    4619.0
# 3   4.0      ROOPESH BHARDWAJ    M  40.0  GEN      BSP  Elephant    1648.0
# 4   5.0     None of the Above  NaN   NaN  NaN     NOTA      NOTA     764.0
# 5   6.0            BRIJ MOHAN    M  37.0  GEN      SHS     Bow &     477.0
# 7   7.0              SURENDER    M  48.0  GEN  CPI(ML)     Cup &     362.0
# 9   8.0           MANOJ KUMAR    M  42.0  GEN      IND       Hat     218.0
# 10  9.0           AJAY MUDGIL    M  30.0  GEN      IND   Coconut     191.0
# 13  1.0           SANJEEV JHA    M  35.0  GEN     AAAP     Broom  124476.0
#
#     postal     total   %age
# 0    256.0   96143.0  59.97
# 1   1241.0   55851.0  34.84
# 2     24.0    4643.0   2.90
# ...
