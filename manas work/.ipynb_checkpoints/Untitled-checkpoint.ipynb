# %%
#!pip install PyPdf2

# %%
import PyPDF2 as pdf
import tabula

# %%
file=open("2015.pdf",'rb')

# %%
pdfreader=pdf.PdfFileReader(file)

# %%
import pandas as pd

# %%
pag1=pdfreader.getPage(88)
p1=pag1.extractText()
print(p1)
# Out:
# CANDIDATE NAME
# SEXAGE CATEGORY
# PARTY
# POSTAL
# TOTAL
# GENERALVALID VOTES POLLED
# Election Commission of India- State Election, 2015 to the Legislative Assembly Of  NCT OF Delhi
# DETAILED RESULTS
# % VOTES POLLEDSYMBOLNERELA1.ConstituencyTOTAL ELECTORS
# : 241032 SHARAD KUMARM 40 GENAAAP 256  96143  95887  59.97  1BroomNEEL DAMAN KHATRI
# M 44 GENBJP 1241  55851  54610  34.84  2LotusPRAVEEN KUMAR BHUGRA
# M 46 GENINC 24  4643  4619  2.90  3HandROOPESH BHARDWAJ
# M 40 GENBSP 14  1662  1648  1.04  4ElephantNone of the Above
# NOTA
#  3  767  764  0.48  5NOTA
# BRIJ MOHANM 37 GENSHS 1  478  477  0.30  6Bow & ArrowSURENDERM 48 GENCPI(ML)(L) 1  363  362  0.23  7Cup & SaucerMANOJ KUMARM 42 GENIND 0  218  218  0.14  8HatAJAY MUDGIL
# M 30 GENIND 0  191  191  0.12  9Coconut 1540  160316 TOTAL
# : 158776 TURNOUT 66.51BURARI2.ConstituencyTOTAL ELECTORS
# : 288420 SANJEEV JHAM 35 GENAAAP 248  124724  124476  63.82  1BroomGOPAL JHA
# ...

# %%
data=data.splitlines()

# %%
dataList=[]
for li in data:
    dataList.append(li.decode('utf-8'))

# %%
dataList
# Out:
# ['CANDIDATE NAME',
#  'SEXAGE CATEGORY',
#  'PARTY',
#  'POSTAL',
#  'TOTAL',
#  'GENERALVALID VOTES POLLED',
#  'Election Commission of India- State Election, 2015 to the Legislative Assembly Of  NCT OF Delhi',
#  'DETAILED RESULTS',
#  '% VOTES POLLEDSYMBOLNERELA1.ConstituencyTOTAL ELECTORS ',
#  ': 241032 SHARAD KUMARM 40 GENAAAP 256  96143  95887  59.97  1BroomNEEL DAMAN KHATRI',
#  'M 44 GENBJP 1241  55851  54610  34.84  2LotusPRAVEEN KUMAR BHUGRA',
#  'M 46 GENINC 24  4643  4619  2.90  3HandROOPESH BHARDWAJ',
#  'M 40 GENBSP 14  1662  1648  1.04  4ElephantNone of the Above',
#  'NOTA',
#  ' 3  767  764  0.48  5NOTA',
#  'BRIJ MOHANM 37 GENSHS 1  478  477  0.30  6Bow & ArrowSURENDERM 48 GENCPI(ML)(L) 1  363  362  0.23  7Cup & SaucerMANOJ KUMARM 42 GENIND 0  218  218  0.14  8HatAJAY MUDGIL',
#  'M 30 GENIND 0  191  191  0.12  9Coconut 1540  160316 TOTAL',
#  ': 158776 TURNOUT 66.51BURARI2.ConstituencyTOTAL ELECTORS ',
# ...

# %%
# Out:
#   File "<ipython-input-62-5f29f2c981ae>", line 1
#     import pdftable-extract as pte
#                    ^
# SyntaxError: invalid syntax

# %%
import camelot

# %%
pdf=camelot.read_pdf('updated.pdf',decode='utf-8',flavour='stream')

# %%
from io import StringIO

# %%
ddd=pdfreader.getPage(88)

# %%
dd=ddd.extractText()

# %%
buf=StringIO(dd)

# %%
buf.readlines()
# Out:
# ['CANDIDATE NAME\n',
#  'SEXAGE CATEGORY\n',
#  'PARTY\n',
#  'POSTAL\n',
#  'TOTAL\n',
#  'GENERALVALID VOTES POLLED\n',
#  'Election Commission of India- State Election, 2015 to the Legislative Assembly Of  NCT OF Delhi\n',
#  'DETAILED RESULTS\n',
#  '% VOTES POLLEDSYMBOLNERELA1.ConstituencyTOTAL ELECTORS \n',
#  ': 241032 SHARAD KUMARM 40 GENAAAP 256  96143  95887  59.97  1BroomNEEL DAMAN KHATRI\n',
#  'M 44 GENBJP 1241  55851  54610  34.84  2LotusPRAVEEN KUMAR BHUGRA\n',
#  'M 46 GENINC 24  4643  4619  2.90  3HandROOPESH BHARDWAJ\n',
#  'M 40 GENBSP 14  1662  1648  1.04  4ElephantNone of the Above\n',
#  'NOTA\n',
#  ' 3  767  764  0.48  5NOTA\n',
#  'BRIJ MOHANM 37 GENSHS 1  478  477  0.30  6Bow & ArrowSURENDERM 48 GENCPI(ML)(L) 1  363  362  0.23  7Cup & SaucerMANOJ KUMARM 42 GENIND 0  218  218  0.14  8HatAJAY MUDGIL\n',
#  'M 30 GENIND 0  191  191  0.12  9Coconut 1540  160316 TOTAL\n',
#  ': 158776 TURNOUT 66.51BURARI2.ConstituencyTOTAL ELECTORS \n',
# ...

# %%
for line in StringIO(dd):
    print(line)
# Out:
# CANDIDATE NAME
#
# SEXAGE CATEGORY
#
# PARTY
#
# POSTAL
#
# TOTAL
#
# GENERALVALID VOTES POLLED
#
# Election Commission of India- State Election, 2015 to the Legislative Assembly Of  NCT OF Delhi
#
# DETAILED RESULTS
#
# % VOTES POLLEDSYMBOLNERELA1.ConstituencyTOTAL ELECTORS
#
# : 241032 SHARAD KUMARM 40 GENAAAP 256  96143  95887  59.97  1BroomNEEL DAMAN KHATRI
#
# M 44 GENBJP 1241  55851  54610  34.84  2LotusPRAVEEN KUMAR BHUGRA
#
# M 46 GENINC 24  4643  4619  2.90  3HandROOPESH BHARDWAJ
#
# M 40 GENBSP 14  1662  1648  1.04  4ElephantNone of the Above
#
# NOTA
#
#  3  767  764  0.48  5NOTA
#
# BRIJ MOHANM 37 GENSHS 1  478  477  0.30  6Bow & ArrowSURENDERM 48 GENCPI(ML)(L) 1  363  362  0.23  7Cup & SaucerMANOJ KUMARM 42 GENIND 0  218  218  0.14  8HatAJAY MUDGIL
#
# M 30 GENIND 0  191  191  0.12  9Coconut 1540  160316 TOTAL
#
# : 158776 TURNOUT 66.51BURARI2.ConstituencyTOTAL ELECTORS
#
# : 288420 SANJEEV JHAM 35 GENAAAP 248  124724  124476  63.82  1BroomGOPAL JHA
#
# ...

# %%
filepath = 'updated.pdf'
with open(filepath) as fp:
    line = fp.readline()
    cnt = 1
    while line:
        print("Line {}: {}".format(cnt, line.strip()))
        line = fp.readline()
        cnt += 1
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-25-abe5b48a0359> in <module>
#       1 filepath = 'updated.pdf'
#       2 with open(filepath) as fp:
# ----> 3     line = fp.readline()
#       4     cnt = 1
#       5     while line:
#
# c:\users\dell\appdata\local\programs\python\python37\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 193: character maps to <undefined>

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

# %%
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
text=convert_pdf_to_txt("updated.pdf")

# %%
print(text)
# Out:
# 
#
# 
#
# 
#
#   
#
# 
#
# 
#
#  
#
# 
#
# 
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
#  
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
#  
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
#  
#
# 
#
# 
#
# 
#
#  
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
#  
#
# 
#
# 
#
# 
#
# 
#
#  
#
# 
#
# 
#
# 
#
# 
#
#  
#
# 
#
# 
#
# 
#
#  
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
#
# 
# 
#
# 
# 
#
# 
#
# 
#
# 
#
# 
#
# ...

# %%
df=pd.DataFrame(text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-a86ecf9bf7ff> in <module>
# ----> 1 df=pd.DataFrame(text)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     483                 )
#     484             else:
# --> 485                 raise ValueError("DataFrame constructor not properly called!")
#     486
#     487         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
def parsedocument(document):
    # convert all horizontal text into a lines list (one entry per line)
    # document is a file stream
    lines = []
    rsrcmgr = PDFResourceManager()
    laparams = LAParams()
    device = PDFPageAggregator(rsrcmgr, laparams=laparams)
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.get_pages(document):
            interpreter.process_page(page)
            layout = device.get_result()
            for element in layout:
                if isinstance(element, LTTextBoxHorizontal):
                    lines.extend(element.get_text().splitlines())
    return lines
