# %% [markdown]
# # Multivariate normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean=np.array([4.0,6.0])
cov=np.array([[0.6,0.3],[0.3,0.8]])

dist=np.random.multivariate_normal(mean,cov,500)

plt.scatter(dist[:,0],dist[:,1])
plt.show()
