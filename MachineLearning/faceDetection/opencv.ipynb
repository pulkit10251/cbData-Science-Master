# %%
import cv2

# %%
# read image
img=cv2.imread('Dog.png')
newimg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
plt.show()
plt.imshow(newimg)
plt.show()

# %%
img=cv2.imread("Dog.png")
drn=cv2.imread('drone.png',cv2.IMREAD_GRAYSCALE)
cv2.imshow('dog pic',img)

cv2.imshow('drone pic',drn)

cv2.waitKey(0)
cv2.destroyAllWindows()
