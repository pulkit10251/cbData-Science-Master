# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,y=make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
plt.figure(0)
plt.grid("True")
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
k=5

colors=["green","red","blue","yellow","orange"]

clusters={}

for i in range(k):
    center=10*(2*np.random.random((X.shape[1],))-1)
    points=[]
    cluster={
        'center':center,
        'points':points,
        'color':colors[i]
    }
    clusters[i]=cluster

# %%
#center=10*(2*np.random.random((X.shape[1],))-1)
#print(center)

# %%
print(clusters)
# Out:
# {0: {'center': array([4.77097114, 8.0734482 ]), 'points': [], 'color': 'green'}, 1: {'center': array([-6.73309011, -5.4875717 ]), 'points': [], 'color': 'red'}, 2: {'center': array([-5.86047766,  1.41141255]), 'points': [], 'color': 'blue'}, 3: {'center': array([-5.92568334,  8.09106602]), 'points': [], 'color': 'yellow'}, 4: {'center': array([-6.38556208, -5.38455112]), 'points': [], 'color': 'orange'}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
# checking
v1=np.array([1,0])
v2=np.array([3,0])
print(distance(v1,v2))
# Out:
# 2.0

# %%
# Assign every point to one of the  clusters
def assignPointsToClusters(clusters): # E - Step
    for ix in range(X.shape[0]):
        dist=[]
        curr_x=X[ix]

        for kx in range(k):
            d=distance(curr_x,clusters[kx]['center'])
            dist.append(d)

        current_cluster=np.argmin(dist)
        clusters[current_cluster]['points'].append(curr_x)
        
def updateClusters(clusters): # M- means update the cluster center acc to mean
    for kx in range(k):
        pts=np.array(clusters[kx]['points'])
        if pts.shape[0]>0:
            new_u=pts.mean(axis=0)
            clusters[kx]['center']=new_u
            clusters[kx]['points']=[]

def plotClusters(clusters):
    for kx in range(k):
        pts=np.array(clusters[kx]['points'])
        print(pts.shape)
        # plot the points
        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
        except:
            pass
        
        # plot the center
        uk=clusters[kx]['center']
        plt.scatter(uk[0],uk[1],color='black',marker="*")

# %%
plotClusters(clusters)
# Out:
# (0,)
# (0,)
# (0,)
# (0,)
# (0,)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (183, 2)
# (116, 2)
# (190, 2)
# (1, 2)
# (10, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (104, 2)
# (123, 2)
# (154, 2)
# (98, 2)
# (21, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (104, 2)
# (127, 2)
# (103, 2)
# (66, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (99, 2)
# (100, 2)
# (101, 2)
# (100, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (99, 2)
# (98, 2)
# (100, 2)
# (103, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (99, 2)
# (98, 2)
# (100, 2)
# (103, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (99, 2)
# (98, 2)
# (100, 2)
# (103, 2)
