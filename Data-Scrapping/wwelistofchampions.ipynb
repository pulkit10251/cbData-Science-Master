# %%
wwe_url="https://en.wikipedia.org/wiki/List_of_current_champions_in_WWE"

# %%
from urllib.request import urlopen

# %%
wwe_data=urlopen(wwe_url)
wwe_html=wwe_data.read()

# %%
print(wwe_html)
wwe_data.close()
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of current champions in WWE - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_current_champions_in_WWE","wgTitle":"List of current champions in WWE","wgCurRevisionId":911779245,"wgRevisionId":911779245,"wgArticleId":12767523,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia semi-protected pages","Articles with short description","Use mdy dates from October 2018","WWE championships lists"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","Februar
# ...

# %%
from bs4 import BeautifulSoup as soup

# %%
wwe_soup=soup(wwe_html,'html.parser')

# %%
print(wwe_soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of current champions in WWE - Wikipedia</title>
# ...

# %%
tables=wwe_soup.findAll('table',{'class':'wikitable'})
print(len(tables))
# Out:
# 7

# %%
wwe_tables=tables[0]
print(wwe_tables)
# Out:
# <table class="wikitable" style="font-size: 85%;">
# <tbody><tr>
# <th>Championship
# </th>
# <th colspan="2">Current champion(s)
# </th>
# <th>Reign
# </th>
# <th>Date won
# </th>
# <th>Days<br/>held
# </th>
# <th>Location
# </th>
# <th>Notes
# </th></tr>
# <tr>
# <td align="center"><a href="/wiki/WWE_Universal_Championship" title="WWE Universal Championship">WWE Universal Championship</a>
# </td>
# <td align="center"><a class="image" href="/wiki/File:Seth_Rollins_Universal.jpg"><img alt="Seth Rollins Universal.jpg" data-file-height="4032" data-file-width="2268" decoding="async" height="178" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Seth_Rollins_Universal.jpg/100px-Seth_Rollins_Universal.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Seth_Rollins_Universal.jpg/150px-Seth_Rollins_Universal.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Seth_Rollins_Universal.jpg/200px-Seth_Rollins_Universal.jpg 2x" width="100"/></a>
# </td>
# ...

# %%
headers=wwe_tables.find_all('th')
print(headers)
print(len(headers))
# Out:
# [<th>Championship
# </th>, <th colspan="2">Current champion(s)
# </th>, <th>Reign
# </th>, <th>Date won
# </th>, <th>Days<br/>held
# </th>, <th>Location
# </th>, <th>Notes
# </th>]
# 7

# %%
coloum_titles=[ct.text[:-1] for ct in headers]
print(coloum_titles)
# Out:
# ['Championship', 'Current champion(s)', 'Reign', 'Date won', 'Daysheld', 'Location', 'Notes']

# %%
rows_data=wwe_tables.findAll('tr')[1:]
print(len(rows_data))
first_row=rows_data[0].findAll('td',{})
for d in first_row:
    print(d.text[:-1])
# Out:
# 4
# WWE Universal Championship
#
# Seth Rollins
# 2
# August 11, 2019
# 10
# Toronto, Ontario
# Defeated Brock Lesnar at SummerSlam.

# %%
table_rows[]
for rows in rows_data:
    current_row=[]
    row_data=row.findAll('td',{})
    for idx,data in enumerate(row_data):
